# %% [markdown]
# <a href="https://colab.research.google.com/github/Younes-ops/YOLOR-Road-Signs-Object-detection/blob/main/YOLOR_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Aug  7 23:04:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Install necessary dependencies
# %cd /content/gdrive/MyDrive/Assesement/yolor
# %pwd
# Out:
# /content/gdrive/MyDrive/Assesement/yolor
# '/content/gdrive/MyDrive/Assesement/yolor'

# %%
# !pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 14.1 MB/s
#      |████████████████████████████████| 776.7 MB 4.6 kB/s
#      |████████████████████████████████| 12.7 MB 56.4 MB/s
#      |████████████████████████████████| 1.5 MB 48.0 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.12.0+cu113 requires torch==1.12.0, but you have torch 1.7.0 which is incompatible.
# fastai 2.7.7 requires torchvision>=0.8.2, but you have torchvision 0.8.1 which is incompatible.

# %%
# install mish-cuda if you want to use mish activation
# https://github.com/thomasbrandon/mish-cuda
# https://github.com/JunnYu/mish-cuda
# !rm -r mish-cuda
# !git clone https://github.com/JunnYu/mish-cuda
# %cd mish-cuda
# !python setup.py build install
# %cd ..
# Out:
# Cloning into 'mish-cuda'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 195 (delta 7), reused 79 (delta 3), pack-reused 107
# Receiving objects: 100% (195/195), 208.77 KiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# /content/gdrive/MyDrive/Assesement/yolor/mish-cuda
# /usr/lib/python3.7/distutils/extension.py:131: UserWarning: Unknown Extension options: 'headers'
#   warnings.warn(msg)
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/mish_cuda
# copying src/mish_cuda/__init__.py -> build/lib.linux-x86_64-3.7/mish_cuda
# running egg_info
# creating src/mish_cuda.egg-info
# writing src/mish_cuda.egg-info/PKG-INFO
# writing dependency_links to src/mish_cuda.egg-info/dependency_links.txt
# writing requirements to src/mish_cuda.egg-info/requires.txt
# ...

# %%
# Install PyTorch Wavelets
# !git clone https://github.com/fbcotter/pytorch_wavelets
# %cd pytorch_wavelets
# !pip install .
# %cd ..
# Out:
# fatal: destination path 'pytorch_wavelets' already exists and is not an empty directory.
# /content/gdrive/MyDrive/Assesement/yolor/pytorch_wavelets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/gdrive/MyDrive/Assesement/yolor/pytorch_wavelets
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for pytorch-wavelets: filename=pytorch_wavelets-1.3.0-py3-none-any.whl size=54869 sha256=40d9d32edf7d36dd216491f76fa8d7ddc522af81a0250869c714bfcc8d7d6f0d
# ...

# %%
# !pip install wandb
# %pwd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 16.1 MB/s
# ...
#      |████████████████████████████████| 157 kB 62.7 MB/s
# ...
#      |████████████████████████████████| 181 kB 72.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 157 kB 74.4 MB/s
# ...
#      |████████████████████████████████| 156 kB 81.7 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=c3416c6238960bf6ccbd350699275e34e50ceefbf5e4d3f6397baae67efbd3e8
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
# '/content/gdrive/MyDrive/Assesement/yolor'

# %%
# !wandb login 20081127473cd069882af79b1e81a96c0bcd182b
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
#!python train.py --batch-size 6 --img 1280 --data gtsdb.yaml --cfg cfg/yolor_p6.cfg --weights runs/train/without_augmentation/weights/last.pt --device 0 --name without_augmentation --hyp hyp.finetune.1280.yaml --epochs 100

# %%
#!python train.py --batch-size 6 --img 1280 --data gtsdb.yaml --cfg cfg/yolor_p6.cfg --weights yolor_p6.pt --device 0 --name momemtum_0_96 --hyp hyp.finetune.1280_4.yaml --epochs 100

# %%
# !python test.py --data data/gtsdb.yaml --names data/gtsdb.names --task test --img 1280 --batch 32 --conf 0.001  --device 0 --cfg cfg/yolor_p6.cfg --weights runs/train/momemtum_0_982/weights/best.pt --name test_best_momentum098 --verbose --save-txt --save-conf
# Out:
# Namespace(augment=False, batch_size=32, cfg='cfg/yolor_p6.cfg', conf_thres=0.001, data='data/gtsdb.yaml', device='0', exist_ok=False, img_size=1280, iou_thres=0.65, name='test_best_momentum098', names='data/gtsdb.names', project='runs/test', save_conf=True, save_json=False, save_txt=True, single_cls=False, task='test', verbose=True, weights=['runs/train/momemtum_0_982/weights/best.pt'])
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 37265016 parameters, 37265016 gradients, 81.842611200 GFLOPS
# Scanning labels ../Data/labels/test.cache3 (78 found, 0 missing, 12 empty, 0 duplicate, for 90 images): 90it [00:00, 18253.74it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:12<00:00,  4.17s/it]
#                  all          90         134       0.847       0.989       0.982       0.878
#               danger          90          22       0.845       0.955       0.969       0.874
# ...

# %%
# !python test.py --data data/gtsdb.yaml --names data/gtsdb.names --task test --img 1280 --batch 32 --conf 0.001  --device 0 --cfg cfg/yolor_p6.cfg --weights runs/train/momemtum_0_982/weights/last.pt --name test_last_momentum098 --verbose --save-txt --save-conf
# Out:
# Namespace(augment=False, batch_size=32, cfg='cfg/yolor_p6.cfg', conf_thres=0.001, data='data/gtsdb.yaml', device='0', exist_ok=False, img_size=1280, iou_thres=0.65, name='test_last_momentum098', names='data/gtsdb.names', project='runs/test', save_conf=True, save_json=False, save_txt=True, single_cls=False, task='test', verbose=True, weights=['runs/train/momemtum_0_982/weights/last.pt'])
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 37265016 parameters, 37265016 gradients, 81.842611200 GFLOPS
# Scanning labels ../Data/labels/test.cache3 (78 found, 0 missing, 12 empty, 0 duplicate, for 90 images): 90it [00:00, 17571.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:12<00:00,  4.24s/it]
#                  all          90         134       0.847       0.975       0.985        0.88
#               danger          90          22       0.851       0.955       0.976       0.877
# ...

# %%
#!python detect.py --source ../gtsdb_video.mp4 --names data/gtsdb.names --cfg cfg/yolor_p6.cfg --weights runs/train/momemtum_0_982/weights/last.pt --conf 0.25 --img-size 1280 --device 0
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolor_p6.cfg', classes=None, conf_thres=0.25, device='0', img_size=1280, iou_thres=0.5, names='data/gtsdb.names', output='inference/output', save_txt=False, source='../gtsdb_video.mp4', update=False, view_img=False, weights=['runs/train/momemtum_0_982/weights/last.pt'])
# video 1/1 (1/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.042s)
# video 1/1 (2/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.041s)
# video 1/1 (3/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.038s)
# video 1/1 (4/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.038s)
# video 1/1 (5/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.038s)
# video 1/1 (6/1439) /content/gdrive/MyDrive/Assesement/gtsdb_video.mp4: 768x1280 Done. (0.038s)
# ...
